# %%
#Se importan librerias

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.set(rc={'figure.figsize':(11.7,8.27)})
plt.style.use('fivethirtyeight')

# %%
#Data 

vacunas = pd.read_csv('/Users/rodolfopardo/Downloads/vacunas_covid.csv')

#Tiene como fuente el Ministerio de salud de la Nación

# %% [markdown]
# #### Exploración de nuestros datos

# %%
#Dimensiones

print('Esta base de datos contiene {} filas como {} columnas.'.format(vacunas.shape[0], vacunas.shape[1]))
# Out:
# Esta base de datos contiene 6433141 filas como 15 columnas.

# %%
#Tipos de datos

vacunas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6433141 entries, 0 to 6433140
# Data columns (total 15 columns):
#  #   Column                      Dtype
# ---  ------                      -----
#  0   sexo                        object
#  1   grupo_etario                object
#  2   jurisdiccion_residencia     object
#  3   jurisdiccion_residencia_id  int64
#  4   depto_residencia            object
#  5   depto_residencia_id         int64
#  6   jurisdiccion_aplicacion     object
#  7   jurisdiccion_aplicacion_id  int64
#  8   depto_aplicacion            object
#  9   depto_aplicacion_id         int64
#  10  fecha_aplicacion            object
#  11  vacuna                      object
#  12  condicion_aplicacion        object
#  13  orden_dosis                 int64
#  14  lote_vacuna                 object
# dtypes: int64(5), object(10)
# memory usage: 736.2+ MB

# %%
#Primeros valores de nuestro dataframe

vacunas.head()
# Out:
#   sexo grupo_etario jurisdiccion_residencia  jurisdiccion_residencia_id  \
# 0    M        60-69                 Mendoza                          50
# 1    M        60-69                 Mendoza                          50
# 2    M        18-29                   Salta                          66
# 3    M        18-29                   Salta                          66
# 4    M        40-49              Corrientes                          18
#
#   depto_residencia  depto_residencia_id jurisdiccion_aplicacion  \
# 0    Luján de Cuyo                   63                 Mendoza
# 1    Luján de Cuyo                   63                 Mendoza
# 2          Capital                   28                   Salta
# 3          Capital                   28                   Salta
# 4   General Alvear                   56              Corrientes
#
#    jurisdiccion_aplicacion_id depto_aplicacion  depto_aplicacion_id  \
# 0                          50    Luján de Cuyo                   63
# 1                          50    Luján de Cuyo                   63
# 2                          66          Capital                   28
# 3                          66          Capital                   28
# 4                          18   General Alvear                   56
#
#   fecha_aplicacion      vacuna condicion_aplicacion  orden_dosis lote_vacuna
# 0       2021-04-06     Sputnik                  >60            1    I-250321
# 1       2021-04-09     Sputnik                  >60            1    I-340321
# 2       2021-02-22     Sputnik                Salud            1    I-080121
# 3       2021-04-07     Sputnik                Salud            2   II-090221
# 4       2021-02-22  COVISHIELD                Salud            1    4120Z023

# %%
#Ultimos valores de nuestro dataframe

vacunas.tail()
# Out:
#         sexo grupo_etario jurisdiccion_residencia  jurisdiccion_residencia_id  \
# 6433136    F        80-89                 Mendoza                          50
# 6433137    F        70-79                 Mendoza                          50
# 6433138    F        60-69     Santiago del Estero                          86
# 6433139    M        70-79                Misiones                          54
# 6433140    F        40-49            Buenos Aires                           6
#
#         depto_residencia  depto_residencia_id jurisdiccion_aplicacion  \
# 6433136            Maipú                   70                 Mendoza
# 6433137       Guaymallén                   28                 Mendoza
# 6433138          Capital                   49     Santiago del Estero
# 6433139           Iguazú                   63                Misiones
# 6433140       San Miguel                  760            Buenos Aires
#
#          jurisdiccion_aplicacion_id depto_aplicacion  depto_aplicacion_id  \
# 6433136                          50            Maipú                   70
# 6433137                          50    Luján de Cuyo                   63
# 6433138                          86          Capital                   49
# 6433139                          54           Iguazú                   63
# 6433140                           6      José C. Paz                  412
#
#         fecha_aplicacion   vacuna condicion_aplicacion  orden_dosis  \
# 6433136       2021-03-29  Sputnik                  >60            1
# 6433137       2021-03-31  Sputnik                  >60            1
# 6433138       2021-03-31  Sputnik                  >60            1
# 6433139       2021-03-30  Sputnik                  >60            1
# 6433140       2021-03-31  Sputnik          Estratégico            1
#
#         lote_vacuna
# 6433136    I-220321
# 6433137    I-250321
# 6433138    I-210321
# 6433139    I-060121
# 6433140    I-220321

# %% [markdown]
# #### Comenzando a filtrar nuestra base por Mendoza

# %%
#Filtrando 

vacunas_mdz = vacunas.loc[vacunas['jurisdiccion_residencia'] == "Mendoza", ['sexo', 'grupo_etario', 
                                                                           'jurisdiccion_residencia',
                                                                           'depto_aplicacion',
                                                                            'fecha_aplicacion',
                                                                           'vacuna',
                                                                           'condicion_aplicacion',
                                                                            'orden_dosis'
                                                                           ]]

# %%
#Verificando que tenemos nuestros datos en Mendoza

vacunas_mdz.head()
# Out:
#    sexo grupo_etario jurisdiccion_residencia depto_aplicacion  \
# 0     M        60-69                 Mendoza    Luján de Cuyo
# 1     M        60-69                 Mendoza    Luján de Cuyo
# 9     M        40-49                 Mendoza       San Rafael
# 10    M        60-69                 Mendoza       Guaymallén
# 11    M        60-69                 Mendoza       Guaymallén
#
#    fecha_aplicacion     vacuna condicion_aplicacion  orden_dosis
# 0        2021-04-06    Sputnik                  >60            1
# 1        2021-04-09    Sputnik                  >60            1
# 9        2021-04-09  Sinopharm                Salud            1
# 10       2021-04-08    Sputnik                  >60            1
# 11       2021-04-14  Sinopharm                  >60            1

# %%
#Verificando si tenemos datos actualizados al día de ayer 

vacunas_mdz[vacunas_mdz['fecha_aplicacion'] == "2021-04-19"].count()
# Out:
# sexo                       2994
# grupo_etario               2994
# jurisdiccion_residencia    2994
# depto_aplicacion           2994
# fecha_aplicacion           2994
# vacuna                     2994
# condicion_aplicacion       2994
# orden_dosis                2994
# dtype: int64

# %% [markdown]
# Tenemos 2994 correspondientes al día de ayer en Mendoza. <font color = green><strong>La base de datos está actualizada</strong></font>

# %%
#Corregimos fecha para poder jugar con dicha variable 

vacunas_mdz['fecha_aplicacion'] = pd.to_datetime(vacunas_mdz['fecha_aplicacion'], format = "%Y-%m-%d")

# %% [markdown]
# #### Visualizando datos

# %% [markdown]
# <p><font color= blue>Vacunas aplicadas por día</font></p>

# %%
x = vacunas_mdz.groupby('fecha_aplicacion')['orden_dosis'].count().plot()
plt.title('Vacunas aplicadas en Mendoza diarias', fontsize = 20)
plt.xlabel('Fecha', fontsize = 15)
plt.ylabel('Cantidad de ordenes', fontsize = 15)
plt.show()
plt.savefig('vacunas_aplicadas_por_fecha.png')

# %%
vacunas_mdz.head()
# Out:
#    sexo grupo_etario jurisdiccion_residencia depto_aplicacion  \
# 0     M        60-69                 Mendoza    Luján de Cuyo
# 1     M        60-69                 Mendoza    Luján de Cuyo
# 9     M        40-49                 Mendoza       San Rafael
# 10    M        60-69                 Mendoza       Guaymallén
# 11    M        60-69                 Mendoza       Guaymallén
#
#    fecha_aplicacion     vacuna condicion_aplicacion  orden_dosis
# 0        2021-04-06    Sputnik                  >60            1
# 1        2021-04-09    Sputnik                  >60            1
# 9        2021-04-09  Sinopharm                Salud            1
# 10       2021-04-08    Sputnik                  >60            1
# 11       2021-04-14  Sinopharm                  >60            1

# %%
x = pd.pivot_table(vacunas_mdz, 
              values = 'orden_dosis',
              index = 'depto_aplicacion', 
              columns = 'sexo',
              aggfunc= np.sum)

# %%
sns.barplot(x = 'depto_aplicacion', y = 'orden_dosis', hue = 'sexo', data = vacunas_mdz)
